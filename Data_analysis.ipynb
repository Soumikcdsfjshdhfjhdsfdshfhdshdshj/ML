# %% [markdown]
# #### Univariate , Bivariate And Multivariate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Univariate

# %%
iris_setosa=iris.loc[iris['species']=='setosa']

# %%
iris_virginica=iris.loc[iris['species']=='virginica']
iris_versicolor=iris.loc[iris['species']=='versicolor']

# %%
plt.plot(iris_setosa['petal_length'], np.zeros_like(iris_setosa['sepal_length']),'o')
plt.plot(iris_virginica['petal_length'], np.zeros_like(iris_virginica['sepal_length']),'o')
plt.plot(iris_versicolor['petal_length'], np.zeros_like(iris_versicolor['sepal_length']),'o')
plt.xlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %% [markdown]
# ### Bivariate

# %%
sns.FacetGrid(iris,hue="species").map(plt.scatter,"sepal_length","sepal_width").add_legend();
plt.show()

# %% [markdown]
# ### Multivariate

# %%
sns.pairplot(iris, hue="species", size =5)
# Out:
# C:\Users\soumi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
